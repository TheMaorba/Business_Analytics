# %% [markdown]
# # Notas Clase
#
# Carlos Martín Ferreira Vanegas
#
# Business Analytics
#
# ferrerirac
#
# # Analisis Exploratorio de datos
#
# - Correlacion lineal de Pearson
# - Multicolinealidad
# - Valor de inflacion de la varianza
# - Correlacion policorica
# - Libreria Polycor, mtcars, corrplot
# - Prueba Chi Cuadrado
# - Ley de los grandes numeros
# - Prueba Kolmogorov smirnov
# - Prueba Shapiro wilk
